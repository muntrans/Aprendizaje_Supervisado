# %%
import numpy as np
from sklearn import datasets
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Carga de datos.
iris = datasets.load_iris()
print(iris.target_names)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
# Mostrar características de la tabla de datos.
print("Tabla de datos: %d instancias y %d atributos" % (iris.data.shape[0], iris.data.shape[1]))
print("Valores de la clase:", set(iris.target))
# Out:
# Tabla de datos: 150 instancias y 4 atributos
# Valores de la clase: {np.int64(0), np.int64(1), np.int64(2)}

# %%
# Test: hold-out split 80-20%. PARTICIÓN EXTERNA
X_training, X_test, y_training, y_test = train_test_split(iris.data, iris.target, test_size=0.2, random_state=42) #train_test_split train_test_split(la matriz de datos, el target, el porcentaje de test (20-30%),  una medida de reprodubilidad: una semilla aleatoria que marca como toma los datos y parametros de incio, en caso que haya fold añadimos su número)
  # nos va adevolver:
    # X_training --> la matriz de muestras y atributos para el entrenamiento
    # X_test --> la mtriz de datos para test - lo reservamos para la evaluación
    # y_training --> el target para entrenamiento
    # y_test --> el target para test
valores_test, ocur_test = np.unique(y_test, return_counts=True)
  # valores_test: Guarda los valores únicos que aparecen en y_test (por ejemplo, si es clasificación binaria, serían [0, 1], o las clases que tengas)
  # ocur_test: Guarda cuántas veces aparece cada uno de esos valores (las ocurrencias/frecuencias)
print('Test: ', 'clases:', valores_test, ' ocurrencias: ', ocur_test)
# Out:
# Test:  clases: [0 1 2]  ocurrencias:  [10  9 11]

# %%
# Estandarizar las características de entrenamiento y de test
standardizer = StandardScaler()
X_train = standardizer.fit_transform(X_training)
X_test = standardizer.transform(X_test)

# %%
# Definimos el algoritmo SVM para clasificación - verificar que hiperparámetro funciona mejor
# Esta cross validation nos permite saber cual es la mejor combinación de parámetros para un algoritmo y comparar algoritmos
from sklearn.svm import SVC
svc = SVC(C=0.5, gamma='auto')

# Hacemos el cross-validation interno para seleccionar los mejores hiperparámetros: internamente ya realiza los entrenamientos en cada fold corresponiente y el testeo, devolviendo el promedio de los resultados
results = cross_val_score(svc, X_train, y_training, cv = KFold(n_splits=5)) # usa el metodo KFold
print("Resultados por bolsa: ", results)
print("Accuracy (media +/- desv.): %0.4f +/- %0.4f" % (results.mean(), results.std()))
# Out:
# Resultados por bolsa:  [0.95833333 0.95833333 0.83333333 0.95833333 0.95833333]
# Accuracy (media +/- desv.): 0.9333 +/- 0.0500

# %%
# Una vez entrenado y validado el modelo para seleccionar los mejores hyperparameters, utilizamos todos los datos de
# "train" y "val" para entrenar el modelo definitivo

svc = SVC(C=0.75, gamma='auto')
svc.fit(X_train, y_training) # Entrenamiento (fit)
# Out:
# SVC(C=0.75, gamma='auto')

# %%
# Calcular la accuracy del conjunto de test
test_results = svc.fit(X_test, y_test)
print('Exactitud en test: ', test_results*100, '%')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2617354841.py in <cell line: 0>()
#       1 # Calcular la accuracy del conjunto de test
#       2 test_results = svc.fit(X_test, y_test)
# ----> 3 print('Exactitud en test: ', test_results*100, '%')
#
# TypeError: unsupported operand type(s) for *: 'SVC' and 'int'

# %%
# Extraer las predicciones, en lugar de directamente la accuracy
y_pred = svc.predict(X_test)
print('Predicciones:     ', y_pred)
print('Etiquetas reales: ', y_test)
# Out:
# Predicciones:      [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0]
# Etiquetas reales:  [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0]
