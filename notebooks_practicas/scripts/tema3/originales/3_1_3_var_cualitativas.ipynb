# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Grado' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria'
#  'Master' 'Grado' 'Secundaria' 'Master' 'Master' 'Grado' 'Bachillerato'
#  'Master' 'Secundaria' 'Bachillerato' 'Doctorado' 'Bachillerato' 'Grado'
#  'Master' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Master' 'Grado' 'Grado' 'Bachillerato'
#  'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Grado' 'Master' 'Grado' 'Master' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Doctorado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Doctorado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Doctorado' 'Bachillerato' 'Grado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Doctorado' 'Grado' 'Secundaria'
#  'Grado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Doctorado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Master' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Doctorado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Master' 'Doctorado'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Master'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Master'
#  'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Master' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Master' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Master' 'Secundaria' 'Doctorado'
#  'Grado' 'Master' 'Secundaria' 'Grado' 'Bachillerato' 'Master'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Master' 'Master' 'Master' 'Secundaria' 'Master'
#  'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Master' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Master' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Secundaria' 'Bachillerato' 'Master' 'Grado' 'Secundaria'
#  'Bachillerato' 'Doctorado' 'Secundaria' 'Grado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Doctorado'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Grado'
#  'Master' 'Grado' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Doctorado' 'Grado'
#  'Secundaria' 'Grado' 'Grado' 'Master' 'Bachillerato' 'Master' 'Grado'
#  'Grado' 'Grado' 'Master' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Doctorado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Master' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Grado' 'Doctorado' 'Bachillerato' 'Master'
#  'Bachillerato' 'Secundaria' 'Master' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Grado'
#  'Master' 'Bachillerato' 'Secundaria' 'Grado' 'Master' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Master'
#  'Bachillerato' 'Doctorado' 'Bachillerato' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Master' 'Doctorado'
#  'Grado' 'Secundaria' 'Bachillerato' 'Doctorado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Grado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Master' 'Master' 'Grado' 'Master' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Master' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Doctorado'
#  'Doctorado' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Master' 'Secundaria' 'Grado' 'Secundaria' 'Master' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Doctorado'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria' 'Doctorado' 'Grado'
#  'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Grado' 'Secundaria'
#  'Grado' 'Master' 'Master' 'Grado' 'Master' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Master'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Master' 'Bachillerato' 'Grado' 'Master' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Master'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Secundaria']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()
